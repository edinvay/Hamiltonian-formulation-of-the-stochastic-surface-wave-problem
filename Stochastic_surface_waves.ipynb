# %% [markdown]
# We simulate the system
#
# \begin{equation}
# 	d
# 	\begin{pmatrix}
# 		\eta
# 		\\
# 		v
# 	\end{pmatrix}
# 	=
# 	J \nabla \mathcal H
# 	d t
# 	+
# 	\sum_i J_i \nabla \mathcal H
# 	\circ
# 	d W_i
# 	,
# \end{equation}
#
# with
#
# \begin{equation}
# 	J
# 	=
# 	\begin{pmatrix}
# 		0 & - K^2 \partial_x
# 		\\
# 		- K^2 \partial_x & 0
# 	\end{pmatrix}
# 	\quad
# 	\text{ and }
# 	\quad
# 	J_i
# 	=
# 	\gamma_i
# 	\begin{pmatrix}
# 		g^{-1} \partial_x  & 0
# 		\\
# 		0  &  h^{-1} K^2 \partial_x
# 	\end{pmatrix}
# 	,
# \end{equation}
# and the energy
# \begin{equation}
# 	\mathcal H
# 	=
# 	\frac 12 \int_{\mathbb R}
# 	\left(
# 		g \eta^2 + h \big( K^{-1}v \big)^2 + \eta v^2
# 	\right)
# 	dx
#     .
# \end{equation}

# %%
from __future__ import division
# %matplotlib inline
from comparison import *
from travwave.petviashvili import *

# %% [markdown]
# Main parameters:

# %%
Length = 100
gravity = 1.0
depth = 1.0
Ngrid = 2**10
Ntime = 10**(5 - 0)
Time = 50

epsilon = 0.1
#gamma = np.array([ 1, 1/2, 1/3, 1/4, 1/5, 1/6 ])
gamma = np.array([ 1 ])

gamma = calibrate_noise(gamma, epsilon = epsilon, g = gravity, h = depth)
Ngamma = len(gamma)

time_step = Time / Ntime
sqrt_step = np.sqrt(time_step)
print(time_step)
print(sqrt_step)
print(epsilon)
print(gamma)
# Out:
# 0.0005
# 0.022360679774997897
# 0.1
# [0.4472136]

# %%
Z = np.random.normal(size = (Ngamma, Ntime))

# %%
Znew = deepcopy(Z)

# %% [markdown]
# where each $\{ Z_n^j \} _{n=0}^{\infty}$ is a sequence of independent $N(0, 1)$-distributed
# random variables.
#
# We can also use previously saved random values, see next two cells. They are stored in files 'Random_values_Zxx.mat', where xx stands for the number of experiment.
#
# Warning: there is a problem with shape after saving and loading again!
# It seems that the type of floating numbers changes during these procedures, which affects slightly the final result.

# %%
#name = name_solution_file( 'Experiments', 'Random_values_Z.mat' )
#test_random_values = {
#    'Z' : Z,
#    'gamma' : gamma,
#    'epsilon' : epsilon,
#    'time_step' : time_step,
#    'sqrt_step' : sqrt_step
#}
#scipy.io.savemat(name, test_random_values)

# %%
name = name_solution_file( 'Experiments', 'Random_values_Z03.mat' )
Random_values = dict()
scipy.io.loadmat(name, Random_values)
Z = Random_values['Z']
gamma = Random_values['gamma'][0]
epsilon = Random_values['epsilon'][0][0]
time_step = Random_values['time_step'][0][0]
sqrt_step = Random_values['sqrt_step'][0][0]

# %%
Zload = deepcopy(Z)

# %%
print(np.shape(Znew) == np.shape(Zload))
print(np.shape(Zload))
print(Zload[0])
print(Znew[0])
#plot(Zload[0])
print(gamma)
print(epsilon)
print(time_step)
print(sqrt_step)
# Out:
# True
# (1, 100000)
# [ 0.48391959  0.73792199  0.33535364 ...  0.56324273 -0.19487843
#  -1.42786889]
# [ 0.19440054 -1.17421787 -0.53132981 ...  0.33488295  0.62000158
#   0.11683099]
# [0.4472136]
# 0.1
# 0.0005
# 0.022360679774997897

# %%
alpha = np.sqrt(gravity * depth**3) * epsilon * time_step
z = np.matmul(gamma, Z) * sqrt_step

# %% [markdown]
# Define system in variables $(\eta, v)$:

# %%
ham = bidirectional_whitham.Hamiltonian_Hur(Length, Ngrid, gravity, depth)

solve_ham = Solver(
    ham, time_step,
    right_partB_indices = [(0,1), (1,1)]
)

# %% [markdown]
# Define initial elevation $\eta_0$:

# %%
################################################
x0 = 0
x = ham.nodes
lam = 3.0
a = 0.7
f_lam = 2 / lam * np.log(sqrt(2) + 1)
eta0 = a / ( np.cosh(f_lam * (x - x0)) **2 )
################################################

# %%
u0 = eta0
u0 = ham.apply_sqrt_gD_over_thHD(u0)
v0 = ham.apply_thHD_over_HD(u0) 
#v0 = 0 * v0
Y1 = np.array([eta0, v0])
plot(ham.nodes[400:600], Y1[0][400:600])

# %%
petv = Petviashvili(ham, 1.3)

Solitary = deepcopy(Y1)
for i in range(400):
    Solitary = petv.iteration(Solitary)
plot(ham.nodes, Solitary[0])
#savefig('solitary waves.pdf')

Y1 = Solitary

# %%
solution_ham = [ Y1 ]

# %% [markdown]
# Define operator
# $
#     \exp
# 	\left(
# 		- \alpha D^2
# 	\right)
# $
# as follows

# %%
exp_minus_alphaDD_symbol = np.exp(- alpha * ham.frequencies**2)

def apply_exp_minus_alphaDD(u):
    res0 = ham.apply_operator(u[0], exp_minus_alphaDD_symbol).real
    res1 = ham.apply_operator(u[1], exp_minus_alphaDD_symbol).real
    return np.array([ res0, res1 ])

# %% [markdown]
# The explicit Euler scheme for the stochastic nonlinear system in $(\eta, v)$ has the form
#
#
# \begin{multline*}
# 	\begin{pmatrix}
# 		\eta(t_{n+1})
# 		\\
# 		v(t_{n+1})
# 	\end{pmatrix}
# 	\approx
# 	\begin{pmatrix}
# 		\eta_{n+1}
# 		\\
# 		v_{n+1}
# 	\end{pmatrix}
# 	=
# 	S(\Delta t) \exp
# 	\left(
# 		- \alpha D^2
# 	\right)
# 	\\
# 	\left \{
# 		\text{expB}(u)
# 		+
# 		z(n)
# 		\begin{pmatrix}
# 			\partial_x \eta + \frac 1g v \partial_x v
# 			\\
# 			\partial_x v + \frac 1h K^2 \partial_x (\eta v)
# 		\end{pmatrix}
# 		+
# 		\alpha
# 		\begin{pmatrix}
# 			\partial_x
# 			\left[
# 				\frac 2g v \partial_x v
# 				+
# 				\frac 1{gh} v K^2 \partial_x (\eta v)
# 			\right]
# 			\\
# 			\partial_x
# 			\left[
# 				\frac 2h K^2 \partial_x (\eta v)
# 				+
# 				\frac 1h K^2
# 				\left(
# 					\frac 1g v^2 \partial_x v
# 					+
# 					\frac 1h \eta K^2 \partial_x (\eta v)
# 				\right)
# 			\right]
# 		\end{pmatrix}
# 	\right \}
# 	,
# \end{multline*}
#
#
# where
#
#
# \begin{equation*}
# 	\text{expB}(u)
# 	=
# 	\begin{pmatrix}
# 		\eta
# 		-
# 		K^2 \partial_x (\eta v) \Delta t
# 		\\
# 		v
# 		-
# 		K^2 \partial_x \left( v^2 / 2 \right) \Delta t
# 	\end{pmatrix}
#     ,
# \end{equation*}
#
#
#
# and is realised in the following loop

# %%
N = Ntime
#N = 5000
for i in range(N):
    u = solution_ham[-1]
    expBu = solve_ham.expB_by_Euler(u, 0, 0)
    eta = u[0]
    v = u[1]
    h = ham.depth
    g = ham.gravity
    KDev = (-1/h) * ham[0,1](u)[0]
    Dv = ham.differentiate(v)
    vDv = v * Dv / g
    expBu[0] = expBu[0] + z[i] * ( ham.differentiate(eta) + vDv )
    expBu[1] = expBu[1] + z[i] * ( Dv + KDev )
    temp = 2 * vDv + v * KDev / g
    temp = alpha * ham.differentiate(temp)
    expBu[0] = expBu[0] + temp
    temp = v * vDv + eta * KDev
    temp = ham.apply_thHD_over_HD(temp) / h + 2 * KDev
    temp = alpha * ham.differentiate(temp)
    expBu[1] = expBu[1] + temp
    temp = apply_exp_minus_alphaDD(expBu)
    solution_ham.append( solve_ham.exact(temp, 0) )

# %%
ind = -1
plt.plot(ham.nodes, solution_ham[0][0], 'grey')
plt.plot(ham.nodes, solution_ham[ind][0], 'purple')
savefig('new_Test.pdf')
savefig('new_Test.eps')

# %%
H_ham = []
for sol in solution_ham:
    H_ham.append( ham.Hamiltonian(sol) )
plot(H_ham)

# %%
solution_hamEL = [ Y1 ]

# %% [markdown]
# Define operators
# $
#     \exp
# 	\left(
# 		iDz(n)
# 	\right)
# $
# as follows

# %%
N = Ntime
exp_iDz_symbol = []
for i in range(N):
    exp_iDz_symbol.append( np.exp(1j * ham.frequencies * z[i]) )

def apply_exp_iDz(u, ind):
    res0 = ham.apply_operator(u[0], exp_iDz_symbol[ind]).real
    res1 = ham.apply_operator(u[1], exp_iDz_symbol[ind]).real
    return np.array([ res0, res1 ])

# %% [markdown]
# The explicit Euler scheme for the stochastic nonlinear system in $(\eta, v)$ has the form
#
#
# \begin{multline*}
# 	\begin{pmatrix}
# 		\eta(t_{n+1})
# 		\\
# 		v(t_{n+1})
# 	\end{pmatrix}
# 	\approx
# 	\begin{pmatrix}
# 		\eta_{n+1}
# 		\\
# 		v_{n+1}
# 	\end{pmatrix}
# 	=
# 	S(\Delta t) \exp
# 	\left(
# 		iD z(n)
# 	\right)
# 	\\
# 	\left \{
# 		\text{expB}(u)
# 		+
# 		z(n)
# 		\begin{pmatrix}
# 			\frac 1g v \partial_x v
# 			\\
# 			\frac 1h K^2 \partial_x (\eta v)
# 		\end{pmatrix}
# 		+
# 		\alpha
# 		\begin{pmatrix}
# 			\partial_x
# 			\left[
# 				\frac 1{gh} v K^2 \partial_x (\eta v)
# 			\right]
# 			\\
# 			\partial_x
# 			\left[
# 				\frac 1h K^2
# 				\left(
# 					\frac 1g v^2 \partial_x v
# 					+
# 					\frac 1h \eta K^2 \partial_x (\eta v)
# 				\right)
# 			\right]
# 		\end{pmatrix}
# 	\right \}
# 	,
# \end{multline*}
#
#
# where
#
#
# \begin{equation*}
# 	\text{expB}(u)
# 	=
# 	\begin{pmatrix}
# 		\eta
# 		-
# 		K^2 \partial_x (\eta v) \Delta t
# 		\\
# 		v
# 		-
# 		K^2 \partial_x \left( v^2 / 2 \right) \Delta t
# 	\end{pmatrix}
#     ,
# \end{equation*}
#
#
#
# and is realised in the following loop

# %%
N = Ntime
#N = 5000
for i in range(N):
    u = solution_hamEL[-1]
    expBu = solve_ham.expB_by_Euler(u, 0, 0)
    eta = u[0]
    v = u[1]
    h = ham.depth
    g = ham.gravity
    KDev = (-1/h) * ham[0,1](u)[0]
    Dv = ham.differentiate(v)
    vDv = v * Dv / g
    expBu[0] = expBu[0] + z[i] * vDv
    expBu[1] = expBu[1] + z[i] * KDev
    temp = v * KDev / g
    temp = alpha * ham.differentiate(temp)
    expBu[0] = expBu[0] + temp
    temp = v * vDv + eta * KDev
    temp = ham.apply_thHD_over_HD(temp) / h
    temp = alpha * ham.differentiate(temp)
    expBu[1] = expBu[1] + temp
    temp = apply_exp_iDz(expBu, i)
    solution_hamEL.append( solve_ham.exact(temp, 0) )

# %%
ind = -1
plt.plot(ham.nodes, solution_ham[0][0], 'grey')
#plt.plot(ham.nodes, solution_ham[ind][0], 'purple')
plt.plot(ham.nodes, solution_hamEL[ind][0], 'black')

name = name_solution_file( 'Experiments', 'solution0.' )
savefig( name + 'pdf' )
savefig( name + 'eps' )

# %%
H_hamEL = []
for sol in solution_hamEL:
    H_hamEL.append( ham.Hamiltonian(sol) )
plot(H_hamEL)

# %%
solution_hamELM = [ Y1 ]

# %%
#Milsteine scheme!
N = Ntime
#N = 5000
for i in range(N):
    u = solution_hamELM[-1]
    expBu = solve_ham.expB_by_Euler(u, 0, 0)
    eta = u[0]
    v = u[1]
    h = ham.depth
    g = ham.gravity
    KDev = (-1/h) * ham[0,1](u)[0]
    Dv = ham.differentiate(v)
    vDv = v * Dv / g
    expBu[0] = expBu[0] + z[i] * vDv
    expBu[1] = expBu[1] + z[i] * KDev
    temp = v * KDev / g
    temp = ( 0.5 * z[i]**2 ) * ham.differentiate(temp)
    expBu[0] = expBu[0] + temp
    temp = v * vDv + eta * KDev
    temp = ham.apply_thHD_over_HD(temp) / h
    temp = ( 0.5 * z[i]**2 ) * ham.differentiate(temp)
    expBu[1] = expBu[1] + temp
    temp = apply_exp_iDz(expBu, i)
    solution_hamELM.append( solve_ham.exact(temp, 0) )

# %%
ind = -1
plt.plot(ham.nodes, solution_ham[0][0], 'grey')
#plt.plot(ham.nodes, solution_ham[ind][0], 'purple')
plt.plot(ham.nodes, solution_hamELM[ind][0], 'black')

name = name_solution_file( 'Experiments', 'solution0.' )
savefig( name + 'pdf' )
savefig( name + 'eps' )

# %%
H_hamELM = []
for sol in solution_hamELM:
    H_hamELM.append( ham.Hamiltonian(sol) )
plot(H_hamELM)

# %%
############################################################

# %% [markdown]
# Here we produce figures for the paper

# %%
ind = -1
plt.plot(ham.nodes, solution_ham[0][0], 'grey')
plt.plot(ham.nodes, solution_hamELM[ind][0], 'black')

name = name_solution_file( 'Experiments', 'solution0.' )
savefig( name + 'pdf' )
savefig( name + 'eps' )

# %%
N = len(H_ham)
times = np.linspace(0.0, time_step * (N-1), N)

#plot(times, H_ham_determenistic)
plot(times, H_ham)
plot(times, H_hamEL) #, 'orange'
plot(times, H_hamELM, 'black')


name = name_solution_file( 'Experiments', 'Energy0.' )
savefig( name + 'pdf' )
savefig( name + 'eps' )

# %%
ind = -1

temp = solution_ham[ind][0] - solution_hamELM[ind][0]
plt.plot(ham.nodes, temp) #, 'blue'

temp = solution_hamEL[ind][0] - solution_hamELM[ind][0]
plt.plot(ham.nodes, temp) #, 'orange'

name = name_solution_file( 'Experiments', 'difference0.' )
savefig( name + 'pdf' )
savefig( name + 'eps' )

# %% [markdown]
# Fourier transform
# \begin{equation*}
#     \widehat u (\xi)
#     =
#     \mathcal F u(\xi)
#     =
#     \int e^{-i\xi x} u(x) dx
#     \approx
#     ( x_1 - x_0 ) \sum _{n = 0}^{N-1}
#     e^{-i\xi x_n} u(x_n)
#     =
#     ( x_1 - x_0 ) \mbox{ FFT}(u)(\xi)
# \end{equation*}
#
# We need to plot the dependence of $\log_{10} | \widehat \eta (\xi) |$ on $\xi$

# %%
ind = -1
u = solution_hamELM[ind][0]
u = scipy.fftpack.fft(u)

u = ( ham.nodes[1] - ham.nodes[0] ) * abs(u)
u = np.log10(u)

redundant = np.argmin(ham.frequencies)
freq = np.concatenate([ ham.frequencies[ 0 : redundant ], ham.frequencies[ redundant + 1 : ]  ])
spec = np.concatenate([ u[ 0 : redundant ], u[ redundant + 1 : ]  ])
#print(np.size(freq))
#print(np.size(temp))

plot(freq, spec, '.', markersize = 2, color = 'black')

name = name_solution_file( 'Experiments', 'log_spectrum0.' )
savefig( name + 'pdf' )
savefig( name + 'eps' )

# %%
ind = -1
u = solution_hamELM[ind][0]
u = scipy.fftpack.fft(u)

u = ( ham.nodes[1] - ham.nodes[0] ) * abs(u)
u = np.log10(u)

redundant = np.argmin(ham.frequencies)

freq = np.concatenate([ ham.frequencies[ 0 : redundant ], ham.frequencies[ redundant + 1 : ]  ])
spec = np.concatenate([ u[ 0 : redundant ], u[ redundant + 1 : ]  ])
print(np.size(freq))
print(np.size(temp))
# Out:
# 1023
# 1023

# %%
############################################################

# %%
petv = Petviashvili(ham, 1.274)

Solitary = deepcopy(Y1)
for i in range(400):
    Solitary = petv.iteration(Solitary)
plot(ham.nodes, Solitary[0])
#savefig('solitary waves.pdf')

#Y1 = Solitary

# %%
ind = -1
x = ham.nodes[790:850] -60
y = solution_hamELM[ind][0][790:850]
plt.plot(x, y, 'black')

x = ham.nodes[483:543]
y = Solitary[0][483:543]
plt.plot(x, y, 'blue')

ind = 9 * 10**4
x = ham.nodes[770:830] -55.2
y = solution_hamELM[ind][0][770:830]
plt.plot(x, y, 'red')



name = name_solution_file( 'Experiments', 'solution0.' )
savefig( name + 'pdf' )
savefig( name + 'eps' )

# %% [markdown]
# We simulate the linear noise system
#
# \begin{equation}
# 	d
# 	\begin{pmatrix}
# 		\eta
# 		\\
# 		v
# 	\end{pmatrix}
# 	=
# 	J \nabla \mathcal H
# 	d t
# 	+
# 	\sum_i J_i \nabla \mathcal H_0
# 	\circ
# 	d W_i
# 	,
# \end{equation}
#
# with
#
# \begin{equation}
# 	J
# 	=
# 	\begin{pmatrix}
# 		0 & - K^2 \partial_x
# 		\\
# 		- K^2 \partial_x & 0
# 	\end{pmatrix}
# 	\quad
# 	\text{ and }
# 	\quad
# 	J_i
# 	=
# 	\gamma_i
# 	\begin{pmatrix}
# 		g^{-1} \partial_x  & 0
# 		\\
# 		0  &  h^{-1} K^2 \partial_x
# 	\end{pmatrix}
# 	,
# \end{equation}
# and the energy
# \begin{equation}
# 	\mathcal H
# 	=
# 	\frac 12 \int_{\mathbb R}
# 	\left(
# 		g \eta^2 + h \big( K^{-1}v \big)^2 + \eta v^2
# 	\right)
# 	dx
#     .
# \end{equation}
#
# Here the noise is defined by
# \begin{equation}
# 	\mathcal H_0
# 	=
# 	\frac 12 \int_{\mathbb R}
# 	\left(
# 		g \eta^2 + h \big( K^{-1}v \big)^2
# 	\right)
# 	dx
#     .
# \end{equation}

# %% [markdown]
# The corresponding explicit Euler scheme
# for the stochastic nonlinear system in $(\eta, v)$ has the form
#
#
# \begin{multline*}
# 	\begin{pmatrix}
# 		\eta(t_{n+1})
# 		\\
# 		v(t_{n+1})
# 	\end{pmatrix}
# 	\approx
# 	\begin{pmatrix}
# 		\eta_{n+1}
# 		\\
# 		v_{n+1}
# 	\end{pmatrix}
# 	=
# 	S(\Delta t) \exp
# 	\left(
# 		iD z(n)
# 	\right)
# 	\text{expB}(u)
# 	,
# \end{multline*}
#
#
# where
#
#
# \begin{equation*}
# 	\text{expB}(u)
# 	=
# 	\begin{pmatrix}
# 		\eta
# 		-
# 		K^2 \partial_x (\eta v) \Delta t
# 		\\
# 		v
# 		-
# 		K^2 \partial_x \left( v^2 / 2 \right) \Delta t
# 	\end{pmatrix}
#     ,
# \end{equation*}
#
#
#
# and is realised in the following loop

# %%
solution_ham_linear_noise = [ Y1 ]

# %%
N = Ntime
#N = 5000
for i in range(N):
    u = solution_ham_linear_noise[-1]
    expBu = solve_ham.expB_by_Euler(u, 0, 0)
    temp = apply_exp_iDz(expBu, i)
    solution_ham_linear_noise.append( solve_ham.exact(temp, 0) )

# %%
ind = -1
plot(ham.nodes, solution_ham[0][0], 'grey')
plot(ham.nodes, solution_ham[ind][0], 'purple')
plot(ham.nodes, solution_hamELM[ind][0], 'black')
plot(ham.nodes, solution_ham_linear_noise[ind][0], 'red')



name = name_solution_file( 'Experiments', 'solution0.' )
savefig( name + 'pdf' )
savefig( name + 'eps' )

# %%
H_ham_linear_noise = []
for sol in solution_ham_linear_noise:
    H_ham_linear_noise.append( ham.Hamiltonian(sol) )
plot(H_ham_linear_noise)

# %%
N = len(H_ham)
times = np.linspace(0.0, time_step * (N-1), N)

#plot(times, H_ham_determenistic)
plot(times, H_ham)
plot(times, H_hamEL)
plot(times, H_hamELM)
plot(times, H_ham_linear_noise)




name = name_solution_file( 'Experiments', 'Energy0.' )
savefig( name + 'pdf' )
savefig( name + 'eps' )

# %% [markdown]
# The explicit Euler scheme for the determenistic nonlinear system in $(\eta, v)$ has the form
#
# \begin{equation*}
# 	\begin{pmatrix}
# 		\eta(t_{n+1})
# 		\\
# 		v(t_{n+1})
# 	\end{pmatrix}
# 	\approx
# 	\begin{pmatrix}
# 		\eta_{n+1}
# 		\\
# 		v_{n+1}
# 	\end{pmatrix}
# 	=
# 	\mathcal S_{\eta, v}(\Delta t)
# 	\begin{pmatrix}
# 		\eta_n
# 		-
# 		\mathcal K \partial_x (\eta_n v_n) \Delta t
# 		\\
# 		v_n
# 		-
# 		\mathcal K \partial_x \left( v_n^2 / 2 \right) \Delta t
# 	\end{pmatrix}
# 	,
# \end{equation*}
#
#
# and is realised in the following loop

# %%
determenistic_ham = [ Y1 ]
N = Ntime
for i in range(N):
    temp = solve_ham.expB_by_Euler(determenistic_ham[-1], 0, 0)
    determenistic_ham.append( solve_ham.exact(temp, 0) )

# %%
ind = -1
plt.plot(ham.nodes, determenistic_ham[ind][0], 'grey')

# %%
ind = -1

#difference = solution_eq[ind][0] - solution_ham[ind][0]
difference = determenistic_ham[ind][0] - solution_ham_linear_noise[ind][0]

plt.plot(ham.nodes, difference, 'black')

# %%
plot(ham.nodes[300:800], solution_ham_linear_noise[ind][0][300:800])
plot(ham.nodes[300:800], difference[300:800])

# %%
ind = -1
plt.plot(ham.nodes, determenistic_ham[ind][0], 'grey')
plot(ham.nodes, solution_ham_linear_noise[ind][0], 'red')

# %%
N = Ntime
u = deepcopy(determenistic_ham[ind])
for i in range(N):
    u = apply_exp_iDz(u, i)

# %%
#plot(ham.nodes, solution_ham_linear_noise[ind][0], 'red')
#plot(ham.nodes, u[0], 'blue')
difference = solution_ham_linear_noise[ind][0] - u[0]
plot(ham.nodes, difference, 'black')

# %%
ind = -1
#u = solution_hamELM[ind][0]
u = solution_ham_linear_noise[ind][0]
u = scipy.fftpack.fft(u)
Ru = u.real
Iu = u.imag
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-fe626b980bb5> in <module>
#       1 ind = -1
#       2 #u = solution_hamELM[ind][0]
# ----> 3 u = solution_ham_linear_noise[ind][0]
#       4 u = scipy.fftpack.fft(u)
#       5 Ru = u.real
#
# NameError: name 'solution_ham_linear_noise' is not defined

# %%
#plot(eq.frequencies[300: 400], Ru[300: 400])
plot(ham.frequencies, Iu)
savefig('new_Test.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-6db3cc7f795c> in <module>
#       1 #plot(eq.frequencies[300: 400], Ru[300: 400])
# ----> 2 plot(ham.frequencies, Iu)
#       3 savefig('new_Test.pdf')
#
# NameError: name 'Iu' is not defined

# %%
H_ham_determenistic = []
for sol in determenistic_ham:
    H_ham_determenistic.append( ham.Hamiltonian(sol) )
plot(H_ham_determenistic)

# %%
H_ham = []
for sol in solution_ham:
    H_ham.append( ham.Hamiltonian(sol) )
plot(H_ham)

# %%
N = len(H_ham)
times = np.linspace(0.0, time_step * (N-1), N)
plot(times, H_ham)
savefig('new_Test_Energy.pdf')
savefig('new_Test_Energy.eps')

# %%
#plot(times, H_ham_determenistic)
plot(times, H_ham)
plot(times, H_hamEL)
plot(times, H_hamELM)


name = name_solution_file( 'Experiments', 'Energy0.' )
savefig( name + 'pdf' )
savefig( name + 'eps' )

# %% [markdown]
# Euler solitary wave initial condition:

# %%
name = name_solution_file( 'Dutykh_results', 'solitary029.mat' )
Dutykh_soliton = scipy.io.loadmat(name)

eta0 = interpolate(Dutykh_soliton['eta'][:,0], Dutykh_soliton['nodes'][:,0], eq.nodes)

##########
ws = interpolate(Dutykh_soliton['ws'][:,0], Dutykh_soliton['nodes'][:,0], eq.nodes)
u1 = ws.real
v1 = - ws.imag
eta0_x = eq.apply_operator( eta0, - eq.symbol01 ).real
u0 = u1 + eta0_x * v1
##########

# %%
petv = Petviashvili(ham, 1.3)

Solitary = deepcopy(Y0)
for i in range(400):
    Solitary = petv.iteration(Solitary)

#plot(eq.nodes, Y0[0])
plot(eq.nodes, Solitary[0])

#plot(eq.nodes, Y0[0] - Solitary[0])

savefig('solitary waves.pdf')

# %%
Y1 = Solitary

# %%
solution_ham = [ Y1 ]

# %%
solve_eq = Solver(
    eq, time_step, sixth_order_splitting = True,
    expA_is_exact = True, expA_is_Runge_Kutta4 = False,
    expB_is_exact = False, expB_is_Runge_Kutta4 = True,
    right_partA_indices = [], right_partB_indices = [(0,1), (1,1)]
)

# %%
#mu, sigma = 0, 1 # mean and standard deviation
#s = np.random.normal(mu, sigma, 30)

s = np.random.normal(size = 100000000)

#print(s)

# %%
abs(mu - np.mean(s))
# Out:
# 8.777667069232835e-06

# %%
test_random_values = {
    'Z' : Z,
    'solution' : solution_hamEL
}

name = name_solution_file( 'Experiments', 'cow.mat' )
scipy.io.savemat(name, test_random_values)

# %%
Test = dict()
name = name_solution_file( 'Experiments', 'cow.mat' )
scipy.io.loadmat(name, Test)
print(Test)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Wed Apr 21 10:10:01 2021', '__version__': '1.0', '__globals__': [], 'Z': array([[-0.56952967, -0.54407228, -0.73906432, ..., -0.46237623,
#          1.47145376, -0.4764376 ]])}

# %%
Test = dict()
name = name_solution_file( 'Experiments', 'cow.mat' )
scipy.io.loadmat(name, Test)
#print(Test)
#np.shape( Test['L1'] )
#John_bathy = Test['L1'][0].real + Test['L2'][0].real
Jtime_step = Test['deltat'][0][0].real
Jstep_number = Test['Q'][0][0].real
JNgrid = Test['N'][0][0].real
Jgravity = Test['g'][0][0].real
Jlength = Test['L'][0][0].real /2
Jdepth = Test['h0'][0][0].real
Jbottom = Test['betavec'][0].real
Jeta0 = Test['etaInitial'][0].real
Ju0 = Test['uInitial'][0].real
JetaFinal = Test['etaFinal'][0].real
print(JetaFinal)
# Out:
# [ 0.03212494 -0.0089713  -0.02429825 ...,  0.06830774  0.09349053
#   0.07685484]

# %%
ham = bottom_whitham.Hamiltonian_Hur_bottom(
    Jlength, JNgrid, Jgravity, Jdepth, Jbottom, order = 2
)
solve_ham = Solver(
    ham, Jtime_step, sixth_order_splitting = True,
    expA_is_exact = True, expA_is_Runge_Kutta4 = False,
    expB_is_exact = False, expB_is_Runge_Kutta4 = True,
    right_partA_indices = [],
    right_partB_indices = [(0,1), (1,1), (0, 2),
                          (0, 3), (0, 4), (0, 5), (1, 2), (1, 3)]
)

# %%
solution_ham = [ np.array([ Jeta0, ham.apply_thHD_over_HD(Ju0) ]) ]
